# %%
import geopandas as gpd
data = gpd.read_file("data/INSPIRE_SCHLAEGE_2022_POINT.gpkg")
data.head()
# Out:
#    FS_KENNUNG    SNAR_BEZEICHNUNG  SL_FLAECHE_BRUTTO_HA     GEO_ID  \
# 0  99507124.0  LSE BÄUME / BÜSCHE                   0.0  3041464.0
# 1  99507134.0  LSE BÄUME / BÜSCHE                   0.0  3041302.0
# 2  99507134.0  LSE BÄUME / BÜSCHE                   0.0  3041300.0
# 3  99507134.0  LSE BÄUME / BÜSCHE                   0.0  3041298.0
# 4  99507124.0  LSE BÄUME / BÜSCHE                   0.0  3041462.0
#
#                                           INSPIRE_ID  \
# 0  https://data.inspire.gv.at/0095/3ee31e14-a6ac-...
# 1  https://data.inspire.gv.at/0095/3ee31e14-a6ac-...
# 2  https://data.inspire.gv.at/0095/3ee31e14-a6ac-...
# 3  https://data.inspire.gv.at/0095/3ee31e14-a6ac-...
# 4  https://data.inspire.gv.at/0095/3ee31e14-a6ac-...
#
#                                               GML_ID  \
# 0  AT.0095.3ee31e14-a6ac-4fc6-913a-1a83995aec5a.l...
# 1  AT.0095.3ee31e14-a6ac-4fc6-913a-1a83995aec5a.l...
# 2  AT.0095.3ee31e14-a6ac-4fc6-913a-1a83995aec5a.l...
# ...
